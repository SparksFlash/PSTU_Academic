# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### #2.1: Irregular Shape

# %% [markdown]
# ### #2.4: Value of PI

# %% [markdown]
# Area of circle = pi * r^2
# Area of sqaure = 2r * 2r = 4 r*2
#
# pi * r^2 / 4r^2 = pi / 4 = inside_circle / total
#
# pi = 4 * (inside_cricle / 4)

# %%
np.random.random(size=5)
# Out:
# array([0.44390182, 0.67008028, 0.24901798, 0.47696347, 0.90714303])

# %%
def value_of_pi(n:int):
    x = np.random.random(size=n)
    y = np.random.random(size=n)
    inside_cnt = 0
    val = []
    for i in range(n):
        if(x[i]**2 + y[i]**2 < 1):
            inside_cnt += 1
        value = 4 * (inside_cnt/(i+1))
        val.append(value)
    return value, val

value,val = value_of_pi(200000)
value
# Out:
# 3.14744

# %%
plt.figure(figsize=(10,5))
plt.plot(val,label="estimated value with monte calro")
plt.axhline(y=np.pi,color="red",label="actual pi value",linewidth=2)
plt.xlabel("Iteration :")
plt.ylabel("Value of PI")
plt.ylim(0,4)
plt.xlim(0,1500)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### #2.5: Random walk

# %%
def random
